# %%
def find_replace(x):
    s1 = "placement" 
    r1 = "screening"
    with open( x , 'r') as file:
        data = file.read()
        data = data.replace(s1, r1)
    with open(x , 'w') as file:
        file.write(data)

# %%
find_replace("example.txt")
